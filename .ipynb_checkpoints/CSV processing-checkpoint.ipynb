# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import random
from IPython.display import display, HTML
from IPython.display import display_html

import pandas as pd
import base64  
import numpy as np

# %% [markdown]
# # Critical Formulae
#
# ### Reco
#
# __Phase__
#
# =if(C2="Phase Name",A1+1,A1)
#
# __Task__
#
# =if(C2="Phase Name",0,if(H2="",B1,if(H1="",B1+1,B1)))
#
# ### Testing
#
# __Phase__
#
# =if(C3="Task",A2+1,if(A2="",0,A2))
#
# __Task__
#
# =if(C3="Task",0,if(C3="Name",B2+1,B2))

# %%
dfrates = pd.read_csv("rates.csv",names=['fee_earners','name','rates'])
dfrates
# Out:
#         fee_earners                        name  rates
# 0           Partner               Greg Wildisen    475
# 1         Paralegal  Ramon the second Rollinger    140
# 2         Associate             Judith Johnston    300
# 3  Senior Associate               Rick Seabrook    375

# %%
dfoverrun = pd.read_csv("overrun.csv",names=['overrun','factor'])
dfoverrun = dfoverrun.set_index('overrun')
dfoverrun
# Out:
#                  factor
# overrun
# Highly Unlikely    0.20
# Possible           0.35
# Probable           0.55
# Highly Likely      0.70

# %%
temp = 'temp_'
uat  = 'uat_'
file_Index = 1

def getfiles(Index):
    global temp
    global uat
    global file_Index
    
    file_Index = Index
    
    temp = 'temp_test'
    uat  = 'uat_test'
    
    temp = temp + Index + '.csv'
    uat  = uat + Index + '.csv'
    
    print(f'Using file: {temp} as template file')
    print(f'Using file: {uat} as testing file')

interact_manual(getfiles, Index="1")
# Out:
# interactive(children=(Text(value='1', description='Index'), Button(description='Run Interact', style=ButtonSty…
# <function __main__.getfiles(Index)>

# %%
HTML('''<script> </script> <form action="javascript:IPython.notebook.execute_cells_below()"><input type="submit" id="toggleButton" value="Run Program"></form>''')
# Out:
# <script> </script> <form action="javascript:IPython.notebook.execute_cells_below()"><input type="submit" id="toggleButton" value="Run Program"></form>

# %%
df_temp = pd.read_csv(temp, names=['phase','task','phase_name','assumption','exclusions','required','narrative','fee_earners','best','lowest','highest','worst','overrun'])

df_temp = df_temp.drop(columns = ['phase_name','assumption','exclusions','required','narrative'])
df_temp = df_temp.dropna()
df_temp = df_temp.merge(dfrates)
df_temp = df_temp.drop(columns = ['name'])

df_temp['source']='template'

df_temp = df_temp.sort_values(by = ['phase','task'])
df_temp = df_temp.reset_index(drop=True)
(x,y) = df_temp.shape
print("Printing dimensions of x,y: " , x ,y)
df_temp
# Out:
# Printing dimensions of x,y:  133 10
#      phase  task fee_earners  best lowest highest worst          overrun  \
# 0      1.0   1.0     Partner   1.0    1.5     2.0   3.0         Possible
# 1      1.0   1.0   Associate   1.0    1.5     2.0   3.0         Possible
# 2      1.0   2.0     Partner   1.5    2.0     2.5   3.0         Possible
# 3      1.0   2.0   Associate   1.5    2.0     2.5   3.0         Possible
# 4      1.0   3.0   Associate   1.0    1.5     2.0   3.0         Possible
# 5      1.0   3.0   Paralegal   1.5    2.0     2.5   3.0         Possible
# 6      1.0   4.0   Associate   0.5    1.0     2.0   2.5         Possible
# 7      1.0   4.0   Paralegal   0.5    1.0     2.0   2.5         Possible
# 8      1.0   5.0   Associate   0.5    1.0     1.5   2.0  Highly Unlikely
# 122   12.0   4.0   Paralegal   0.8    1.3     2.3   2.8  Highly Unlikely
# 123   13.0   1.0   Associate   0.3    0.5     0.8   1.0  Highly Unlikely
# 124   13.0   2.0   Associate   0.3    0.5     0.8   1.0  Highly Unlikely
# 125   13.0   3.0   Associate   0.5    0.8     1.0   1.5  Highly Unlikely
# 126   13.0   4.0   Paralegal   1.0    1.5     2.0   3.0  Highly Unlikely
# 127   13.0   5.0   Paralegal   1.0    1.5     2.0   2.5  Highly Unlikely
# 128   13.0   6.0   Associate   1.0    2.0     3.0   4.0  Highly Unlikely
# 129   13.0   6.0   Paralegal   4.0    6.0     9.0  12.0  Highly Unlikely
# 130   13.0   7.0   Associate   0.3    0.5     0.8   1.0  Highly Unlikely
# 131   13.0   8.0     Partner   2.0    3.0     5.0   7.0  Highly Unlikely
# 132   13.0   8.0   Associate   2.0    3.0     5.0   7.0  Highly Unlikely
#
#      rates    source
# 0      475  template
# 1      300  template
# 2      475  template
# 3      300  template
# 4      300  template
# 5      140  template
# 6      300  template
# 7      140  template
# 8      300  template
# 9      300  template
# 10     300  template
# 11     475  template
# 12     300  template
# 13     475  template
# 14     300  template
# 15     300  template
# 16     300  template
# 17     300  template
# 18     475  template
# 19     300  template
# 20     140  template
# 21     300  template
# 22     140  template
# 23     300  template
# 24     140  template
# 25     475  template
# 26     300  template
# 27     140  template
# 28     300  template
# 29     140  template
# ..     ...       ...
# 103    300  template
# 104    140  template
# 105    300  template
# 106    140  template
# 107    475  template
# 108    300  template
# 109    140  template
# 110    300  template
# 111    300  template
# 112    300  template
# 113    475  template
# 114    300  template
# 115    475  template
# 116    300  template
# 117    140  template
# 118    300  template
# 119    300  template
# 120    140  template
# 121    300  template
# 122    140  template
# 123    300  template
# 124    300  template
# 125    300  template
# 126    140  template
# 127    140  template
# 128    300  template
# 129    140  template
# 130    300  template
# 131    475  template
# 132    300  template
#
# [133 rows x 10 columns]

# %%
df_UAT = pd.read_csv(uat, names = ['phase','task','name','rate','best','lowest','highest','worst','overrun'])

df_UAT = df_UAT.drop(columns = ['rate'])
df_UAT = df_UAT.dropna()
df_UAT = df_UAT.merge(dfrates)
df_UAT = df_UAT.drop(columns = ['name'])

df_UAT['source'] = 'testing'

list = df_temp.columns.tolist()
df_UAT = df_UAT[list]

df_UAT = df_UAT.sort_values(by = ['phase','task'])
df_UAT = df_UAT.reset_index(drop=True)
(x,y) = df_UAT.shape
print("Printing dimensions of x,y: " , x ,y)
df_UAT
# Out:
# Printing dimensions of x,y:  119 10
#      phase  task fee_earners best lowest highest worst          overrun  \
# 0      1.0   1.0     Partner    1    1.5       2     3         Possible
# 1      1.0   1.0   Associate    1    1.5       2     3         Possible
# 2      1.0   2.0     Partner  1.5      2     2.5     3         Possible
# 3      1.0   2.0   Associate  1.5      2     2.5     3         Possible
# 4      1.0   3.0   Associate    1    1.5       2     3         Possible
# 5      1.0   3.0   Paralegal  1.5      2     2.5     3         Possible
# 6      1.0   4.0   Associate  0.5      1       2   2.5         Possible
# 7      1.0   4.0   Paralegal  0.5      1       2   2.5         Possible
# 8      1.0   5.0   Associate  0.5      1     1.5     2  Highly Unlikely
# 9      1.0   6.0   Associate    1    1.5       2   2.5  Highly Unlikely
# 10     2.0   1.0   Associate    2    2.5       3     4         Probable
# 11     2.0   2.0     Partner    1    1.5       2   2.5         Possible
# 12     2.0   2.0   Associate  1.3    1.8     2.5     3         Possible
# 13     2.0   3.0     Partner  0.5    0.8       1   1.5  Highly Unlikely
# 14     2.0   3.0   Associate  0.5    0.8       1   1.5  Highly Unlikely
# 15     2.0   4.0   Associate    1      2       3     4         Possible
# 16     2.0   5.0   Associate    3      4       6     8         Probable
# 17     3.0   1.0   Associate    2    2.5       3     5  Highly Unlikely
# 18     3.0   2.0     Partner  0.5    0.8       1   1.5  Highly Unlikely
# 19     3.0   2.0   Associate  0.5    0.8       1   1.5  Highly Unlikely
# 20     3.0   3.0   Paralegal  0.8      1     1.3   1.5  Highly Unlikely
# 21     4.0   1.0   Associate    8     10      12    20  Highly Unlikely
# 22     4.0   1.0   Paralegal    9     12      14    22  Highly Unlikely
# 23     4.0   2.0   Associate   16     25      30    40  Highly Unlikely
# 24     4.0   2.0   Paralegal   18     27      32    45  Highly Unlikely
# 25     4.0   3.0     Partner  0.5    1.5     2.5     3         Possible
# 26     4.0   3.0   Associate  0.5    1.5     2.5     3         Possible
# 27     4.0   3.0   Paralegal  0.5    1.5     2.5     3         Possible
# 28     4.0   4.0   Associate   10     14      16    20         Probable
# 29     4.0   4.0   Paralegal   10     14      16    20         Probable
# ..     ...   ...         ...  ...    ...     ...   ...              ...
# 89    10.0   2.0   Associate  0.2    0.5     0.8     1  Highly Unlikely
# 90    10.0   3.0   Associate    1      2       3     4         Possible
# 91    10.0   3.0   Paralegal    2    2.5       3     4         Possible
# 92    10.0   4.0   Associate    1    1.5     2.5     3  Highly Unlikely
# 93    10.0   4.0   Paralegal    1    1.5     2.5     3  Highly Unlikely
# 94    10.0   5.0     Partner    2      3       4     6         Possible
# 95    10.0   5.0   Associate    2      3       4     6         Possible
# 96    11.0   1.0   Associate  0.3    0.5     0.8     1  Highly Unlikely
# 97    11.0   2.0   Associate  0.5      1       2     3         Possible
# 98    11.0   3.0   Associate    1    1.5       3     5  Highly Unlikely
# 99    11.0   4.0     Partner  0.3    0.5     0.8     1  Highly Unlikely
# 100   11.0   4.0   Associate    1    1.5     1.8     2  Highly Unlikely
# 101   11.0   5.0     Partner  0.5      1     1.5     2  Highly Unlikely
# 102   11.0   5.0   Associate  0.5      1     1.5     2  Highly Unlikely
# 103   12.0   1.0   Paralegal  0.5      1       2     3         Possible
# 104   12.0   2.0   Associate  0.2    0.5     0.8     1  Highly Unlikely
# 105   12.0   3.0   Associate  0.5      1     1.5     2         Possible
# 106   12.0   3.0   Paralegal    1    1.3     1.5     2         Possible
# 107   12.0   4.0   Associate  0.8    1.3     2.3   2.8  Highly Unlikely
# 108   12.0   4.0   Paralegal  0.8    1.3     2.3   2.8  Highly Unlikely
# 109   13.0   1.0   Associate  0.3    0.5     0.8     1  Highly Unlikely
# 110   13.0   2.0   Associate  0.3    0.5     0.8     1  Highly Unlikely
# 111   13.0   3.0   Associate  0.5    0.8       1   1.5  Highly Unlikely
# 112   13.0   4.0   Paralegal    1    1.5       2     3  Highly Unlikely
# 113   13.0   5.0   Paralegal    1    1.5       2   2.5  Highly Unlikely
# 114   13.0   6.0   Associate    1      2       3     4  Highly Unlikely
# 115   13.0   6.0   Paralegal    4      6       9    12  Highly Unlikely
# 116   13.0   7.0   Associate  0.3    0.5     0.8     1  Highly Unlikely
# 117   13.0   8.0     Partner    2      3       5     7  Highly Unlikely
# 118   13.0   8.0   Associate    2      3       5     7  Highly Unlikely
#
#      rates   source
# 0      475  testing
# 1      300  testing
# 2      475  testing
# 3      300  testing
# 4      300  testing
# 5      140  testing
# 6      300  testing
# 7      140  testing
# 8      300  testing
# 9      300  testing
# 10     300  testing
# 11     475  testing
# 12     300  testing
# 13     475  testing
# 14     300  testing
# 15     300  testing
# 16     300  testing
# 17     300  testing
# 18     475  testing
# 19     300  testing
# 20     140  testing
# 21     300  testing
# 22     140  testing
# 23     300  testing
# 24     140  testing
# 25     475  testing
# 26     300  testing
# 27     140  testing
# 28     300  testing
# 29     140  testing
# ..     ...      ...
# 89     300  testing
# 90     300  testing
# 91     140  testing
# 92     300  testing
# 93     140  testing
# 94     475  testing
# 95     300  testing
# 96     300  testing
# 97     300  testing
# 98     300  testing
# 99     475  testing
# 100    300  testing
# 101    475  testing
# 102    300  testing
# 103    140  testing
# 104    300  testing
# 105    300  testing
# 106    140  testing
# 107    300  testing
# 108    140  testing
# 109    300  testing
# 110    300  testing
# 111    300  testing
# 112    140  testing
# 113    140  testing
# 114    300  testing
# 115    140  testing
# 116    300  testing
# 117    475  testing
# 118    300  testing
#
# [119 rows x 10 columns]

# %%
look_up_dict = dfoverrun.to_dict()['factor']

df_temp.overrun = df_temp.overrun.map(look_up_dict)
df_UAT.overrun = df_UAT.overrun.map(look_up_dict)

# %%
df_temp

##Can be removed for final version
# Out:
#      phase  task fee_earners  best lowest highest worst  overrun  rates  \
# 0      1.0   1.0     Partner   1.0    1.5     2.0   3.0     0.35    475
# 1      1.0   1.0   Associate   1.0    1.5     2.0   3.0     0.35    300
# 2      1.0   2.0     Partner   1.5    2.0     2.5   3.0     0.35    475
# 3      1.0   2.0   Associate   1.5    2.0     2.5   3.0     0.35    300
# 4      1.0   3.0   Associate   1.0    1.5     2.0   3.0     0.35    300
# 5      1.0   3.0   Paralegal   1.5    2.0     2.5   3.0     0.35    140
# 6      1.0   4.0   Associate   0.5    1.0     2.0   2.5     0.35    300
# 7      1.0   4.0   Paralegal   0.5    1.0     2.0   2.5     0.35    140
# 8      1.0   5.0   Associate   0.5    1.0     1.5   2.0     0.20    300
# 9      1.0   6.0   Associate   1.0    1.5     2.0   2.5     0.20    300
# 10     2.0   1.0   Associate   2.0    2.5     3.0   4.0     0.55    300
# 11     2.0   2.0     Partner   1.0    1.5     2.0   2.5     0.35    475
# 12     2.0   2.0   Associate   1.3    1.8     2.5   3.0     0.35    300
# 13     2.0   3.0     Partner   0.5    0.8     1.0   1.5     0.20    475
# 14     2.0   3.0   Associate   0.5    0.8     1.0   1.5     0.20    300
# 128   13.0   6.0   Associate   1.0    2.0     3.0   4.0     0.20    300
# 129   13.0   6.0   Paralegal   4.0    6.0     9.0  12.0     0.20    140
# 130   13.0   7.0   Associate   0.3    0.5     0.8   1.0     0.20    300
# 131   13.0   8.0     Partner   2.0    3.0     5.0   7.0     0.20    475
# 132   13.0   8.0   Associate   2.0    3.0     5.0   7.0     0.20    300
#
#        source
# 0    template
# 1    template
# 2    template
# 3    template
# 4    template
# 5    template
# 6    template
# 7    template
# 8    template
# 9    template
# 10   template
# 11   template
# 12   template
# 13   template
# 14   template
# 15   template
# 16   template
# 17   template
# 18   template
# 19   template
# 20   template
# 21   template
# 22   template
# 23   template
# 24   template
# 25   template
# 26   template
# 27   template
# 28   template
# 29   template
# ..        ...
# 103  template
# 104  template
# 105  template
# 106  template
# 107  template
# 108  template
# 109  template
# 110  template
# 111  template
# 112  template
# 113  template
# 114  template
# 115  template
# 116  template
# 117  template
# 118  template
# 119  template
# 120  template
# 121  template
# 122  template
# 123  template
# 124  template
# 125  template
# 126  template
# 127  template
# 128  template
# 129  template
# 130  template
# 131  template
# 132  template
#
# [133 rows x 10 columns]

# %%
#Calculation Part

np_temp = df_temp.values
(x,y) = np_temp.shape

costs = np.zeros((x,4))

for i in range(0,x):
    
    costindex = 3
    
    costbest =    float(np_temp[i][costindex  ]) * float(np_temp[i][costindex+5])
    costlow =     float(np_temp[i][costindex+1]) * float(np_temp[i][costindex+5])
    costhigh =    float(np_temp[i][costindex+2]) * float(np_temp[i][costindex+5])
    costworst =   float(np_temp[i][costindex+3]) * float(np_temp[i][costindex+5])
    
    costs[i][0] = costbest
    costs[i][1] = costlow
    costs[i][2] = costhigh
    costs[i][3] = costworst
    
np_temp = np.append(np_temp,costs,axis = 1)

# %%
np_UAT = df_UAT.values
(x,y) = np_UAT.shape

costs = np.zeros((x,4))

for i in range(0,x):
    
    costindex = 3
   
    costbest =    float(np_UAT[i][costindex  ]) * float(np_UAT[i][costindex+5])
    costlow =     float(np_UAT[i][costindex+1]) * float(np_UAT[i][costindex+5])
    costhigh =    float(np_UAT[i][costindex+2]) * float(np_UAT[i][costindex+5])
    costworst =   float(np_UAT[i][costindex+3]) * float(np_UAT[i][costindex+5])
    
    costs[i][0] = costbest
    costs[i][1] = costlow
    costs[i][2] = costhigh
    costs[i][3] = costworst
    
np_UAT = np.append(np_UAT,costs,axis = 1)

# %%
def getmax(array):
    (x,y) = array.shape
    maxval = 0
    for i in range(0,x):
        element = int(array[i][0])
        if (element>=int(maxval)):
            maxval = array[i][0]
    return int(maxval)

# %%
class npElement:
    def __init__(self,nparray,index):
        self.index        = index
        self.phase        = int(nparray[0])
        self.task         = int(nparray[1])
        self.fe           = nparray[2]
        self.best         = float(nparray[3])
        self.lowest       = float(nparray[4])
        self.highest      = float(nparray[5])
        self.worst        = float(nparray[6])
        self.overrun      = float(nparray[7])
        self.rates        = int(nparray[8])
        self.source       = nparray[9]
        self.best_cost    = float(nparray[10])
        self.lowest_cost  = float(nparray[11])
        self.highest_cost = float(nparray[12])
        self.worst_cost   = float(nparray[13])
    
    def costToArray(self):
        return [self.best,self.lowest,self.highest,self.worst,self.best_cost,self.lowest_cost,self.highest_cost,self.worst_cost,self.rates]
    
    def printme(self):
        print("Debug---> ID:",self.index, " Phase: ",self.phase, " Task: ",self.task)
        
    def printPerson(self):
        print("ID: ",self.index, " Phase: ",self.phase, " ,Task: ",self.task, " ,Fee Earner: ", self.fe, "\n")
        
    def calculate_FF(self,debug_costs = False):
        self.lff = np.around((self.worst_cost-(self.highest_cost+self.lowest_cost)*0.5)*self.overrun+(self.highest_cost+self.lowest_cost)*0.5,-1)
        
        self.hff = np.around((self.worst_cost - self.highest_cost) * self.overrun + self.highest_cost,-1)
        
        if debug_costs==True:
            print(f'Highest Fixed Fee: {self.hff}')
            print(f'Lowest Fixed Fee: {self.lff}')
        
    def round_Costs(self,debug_costs = False):
        #debug_costs = True
        self.best_cost_R = int(np.around(self.best_cost,-1))
        self.lowest_cost_R = int(np.around(self.lowest_cost,-1))
        self.highest_cost_R = int(np.around(self.highest_cost,-1))
        self.worst_cost_R = int(np.around(self.worst_cost,-1))
        if debug_costs==True:
            print(f'Best cost:{self.best_cost} --> {self.best_cost_R}')
            print(f'Lowest cost:{self.lowest_cost} --> {self.lowest_cost_R}')
            print(f'Highest cost:{self.highest_cost} --> {self.highest_cost_R}')
            print(f'Worst cost:{self.worst_cost} --> {self.worst_cost_R}')
            print('---------------------------------------------------\n')

# %%
#Precompile lists of npElements
#Format:
#         list[i][j]
#         i is used to denote the phase
#         j is used to denote the task in said phase

def compileList(nparray):
    listofPhases = []
    dummylist = []
    (x,y) = nparray.shape
    
    currentphase = 1

    for i in range(0,x):
        ele_temp = npElement(nparray[i],i)
        #print(nparray[i])
        phase = ele_temp.phase
        if (phase != currentphase):
            currentphase = phase
            listofPhases.append(dummylist)
            dummylist = []
        dummylist.append(ele_temp)
        
    listofPhases.append(dummylist)
        
    return listofPhases

# %%
listOfIndicies = []

    
    

def compareCosts(ele_a,ele_b):
    namelist=["best","lowest","highest","worst","best_cost","lowest_cost","highest_cost","worst_cost"]
    match = False
    cost = []
    cost.append(ele_a.costToArray())
    cost.append(ele_b.costToArray())
#     print("cost[0]:", cost[0])
#     print("cost[1]:", cost[1])
#     print("Task: ",ele_a.task)
#     print("Match:",(cost[0]==cost[1]),"\n")
    if (cost[0] == cost[1]):
        return True
    else:
        print("ID: ", ele_a.index)
        print(f'Phase: {ele_a.phase}')
        print("Task: ",ele_a.task)
        print("Match:",(cost[0]==cost[1]),"\n")
        
        global listOfIndicies
        
        listOfIndicies.append(ele_a.index)
        
        
        for i in range(0,len(cost[0])-1):

            
            if (cost[0][i]!=cost[1][i]):
                name = namelist[i]
                print("Mismatch is found at: ",name)
                print("Values --->",ele_a.source,":",cost[0][i],"|",ele_b.source,":",cost[1][i],"\n")

        return False

# %%
def compareTasks(biggerArray, smallerArray):
    allclear = True
    mismatches = []
    for element_b in biggerArray:
        found = False
        costsMatch = False
        
        
        for element_s in smallerArray:
            if (element_b.phase == element_s.phase):
                if (element_b.task == element_s.task):
                    if (element_b.fe == element_s.fe):
                        if (found == True):print("Dup found")
                        found = True
                        compareCosts(element_b,element_s)
                        
        if (found == False):
            mismatches.append(element_b)
    if (len(mismatches) > 0):
        global listOfIndicies
        
        print("\nPrinting mismatches in task: ")
        allclear = False
        for element in mismatches:
            listOfIndicies.append(element.index)
            element.printPerson()
    return allclear

# %%
# %%capture cap --no-stderr
#Comparing Template to Test

(x1,y1) = np_temp.shape
(x2,y2) = np_UAT.shape

#Go through the longer list and compare to the template
#keeping track of:
#   number of fee_earners in each phase
#   checking if the prices are correct for each
#   suggesting if an incorrect person has been used for that task

listof_temp = compileList(np_temp)
listof_UAT  = compileList(np_UAT)

dummylist = []
currentphase = 1

#comparing number of tasks per phase

phases_temp = len(listof_temp)
phases_UAT  = len(listof_UAT)

matchingFlag = 0  # if both phases match = 0
                  #    temp > uat        = 1
                  #    temp < uat        = 2

if (phases_temp>phases_UAT):
    print("There are fewer phases in UAT than in Template")
    index = phases_temp
    matchingFlag = 1
elif (phases_temp < phases_UAT):
    print("There are more phases in UAT than in Template")
    index = phases_UAT
    matchingFlag = 2
else:
    print("   ----------\n  Phases match   \n   ----------\n")
    index = phases_temp
allclear = True
for i in range(0,index):
    
    if ((i < phases_temp) and (i < phases_UAT)): # case if the index is within both phases
        tasks_t = len(listof_temp[i])
        tasks_u = len(listof_UAT[i])
        
        if not tasks_t == tasks_u:
            print("--- Checking tasks in phase: ",i+1," ---")
            print("Tasks in Template: ", tasks_t)
            print("Tasks in UAT:      ", tasks_u)
            print("------------------------------------\n")

        
        if ((tasks_t<tasks_u)or(tasks_t==tasks_u)): #compare the block with more tasks against the smaller one
            allclear_phase = compareTasks(listof_UAT[i],listof_temp[i])     
            
        if allclear == True:
            allclear = allclear_phase
        
        
    elif (i < phases_temp):
        tasks_t = len(listof_temp[i])
            
        print("--- Checking tasks in phase: ",i+1," ---")
        print("Tasks do not exist for UAT")
        print("Tasks in Template: ", tasks_t)
        allclear = False
        print("\n")
    elif (i < phases_UAT):
        tasks_u = len(listof_UAT[i])
        print("--- Checking tasks in phase: ",i+1," ---")
        print("Tasks do not exist for Template")
        print("Tasks in UAT:      ", tasks_u)
        allclear = False
        print("\n")
        
    if allclear_phase == False:
        print("----------------------      End of errors in phase       ------------------------\n")

if allclear == True:
    print("All Good :-)\n")

# %%
filename = 'ValuesOutput' + file_Index + '.txt'

with open(filename, 'w') as f:
    f.write(cap.stdout)

# %%
def algo_compute(listof_class):
    df_phase_costs = pd.DataFrame(columns=['phase','task','RBCC','RLAC','RHAC','RWCC','RLFF','RHFF','overrun'])
    current_index = 0
#     bestsum = 0
    for task_list in listof_class:
        for element in task_list:
            
            element.round_Costs()
            element.calculate_FF()
            df_phase_costs.loc[current_index] = [element.phase,element.task,element.best_cost_R,element.lowest_cost_R,element.highest_cost_R,element.worst_cost_R,element.lff,element.hff,element.overrun]
#             bestsum += element.best_cost_R
            current_index += 1
    return df_phase_costs

# %% [markdown]
# # Template Sums

# %%
df_phase_costs_temp = algo_compute(listof_temp)
df_phase_costs_temp.sum(axis = 0, skipna = True)
# Out:
# phase         841.0
# task          704.0
# RBCC       150130.0
# RLAC       200700.0
# RHAC       253660.0
# RWCC       349940.0
# RLFF       284260.0
# RHFF       299130.0
# overrun        46.2
# dtype: float64

# %% [markdown]
# # UAT Sums

# %%
df_phase_costs_uat = algo_compute(listof_UAT)
df_phase_costs_uat.sum(axis = 0, skipna = True)
# Out:
# phase         779.0
# task          564.0
# RBCC       116900.0
# RLAC       161130.0
# RHAC       207750.0
# RWCC       285270.0
# RLFF       217640.0
# RHFF       233190.0
# overrun        34.6
# dtype: float64

# %% [markdown]
# # Checking inconsistancies

# %%
# %%capture cap --no-stderr

(x1,y1) = df_phase_costs_temp.shape
(x2,y2) = df_phase_costs_uat.shape

if not x1==x2:
    print(f'Number of phases does not match: {x1} in templates, {x2} in UAT \n')
    
else:
    fields = df_phase_costs_temp.columns



    for i in range(0,x1-1):
        for j in range(0,y1):
            debug_on = False
            field_temp = df_phase_costs_temp.loc[i].iloc[j]
            field_uat  = df_phase_costs_uat.loc[i].iloc[j]

            if debug_on == True:
                print(f'{fields[j]}: temp:{field_temp} -- uat:{field_uat}')

            if not df_phase_costs_temp.loc[i].iloc[j] == df_phase_costs_uat.loc[i].iloc[j]:
                print(f'Mismatch in {fields[j]} --> phase: {df_phase_costs_temp.loc[i].phase} task: {df_phase_costs_temp.loc[i].task}')
                print(f'Template: {field_temp} ---> UAT: {field_uat}\n')
                ele_temp = df_phase_costs_temp.loc[i]
                ele_uat  = df_phase_costs_uat.loc[i]
    # #             if not (ele_temp.overrun == ele_uat.overrun):
    #                 print(f'Overrun risk does not match')

    # with open('output.txt', 'w') as f:
    #     f.write(cap.stdout)

    df_phase_costs_temp = algo_compute(listof_temp)
    sum_temp = df_phase_costs_temp.sum(axis = 0, skipna = True)

    df_phase_costs_uat = algo_compute(listof_UAT)
    sum_uat = df_phase_costs_uat.sum(axis = 0, skipna = True) 

    print(f'Sum for template costs:\n{sum_temp} \n ------------------------- \n')

    print(f'Sum for UAT costs:\n{sum_uat}')

# %%
# task =1#.sum(axis = 0, skipna = True)
# print(df_phase_costs_temp[df_phase_costs_temp.phase == task])
# print(df_phase_costs_uat[df_phase_costs_uat.phase == task])

filename = 'AlgoOutput' + file_Index + '.txt'

with open(filename, 'w') as f:
    f.write(cap.stdout)

# %%
def dfdisp(df,x,full):
    global listOfIndicies
    global listOfHLD
    if (full == False):
        dfa = df[df.phase == x]
        #     dfa.style.apply(highlight_max)
        #display(dfa.style.apply(highlight_max, subset=['best','lowest','highest','worst']))
#         display(dfa.style.apply(lambda x: ['background: lightcoral' if x.name in listOfIndicies else '' for i in x], 
#                axis=1))
            
        dfa = dfa.style.apply(lambda x: ['background: lightcoral' if x.name in listOfIndicies else '' for i in x], 
                    axis=1)
        display (dfa)
    else:
        display(df.style.apply(lambda x: ['background: lightcoral' if x.name in listOfIndicies else '' for i in x], 
               axis=1))

def filter(Full_List,x):
    dfdisp(df_temp,x,Full_List)
    dfdisp(df_UAT,x,Full_List)
    
interact(filter,Full_List=True, x=(1,10,1));
# Out:
# interactive(children=(Checkbox(value=True, description='Full_List'), IntSlider(value=5, description='x', max=1…
